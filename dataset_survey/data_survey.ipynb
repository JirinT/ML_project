# %%
import pandas as pd

# %%
df = pd.read_csv("caxton_dataset_final.csv")
df
# Out:
#                                       img_path               timestamp  \
# 0            caxton_dataset/print0/image-6.jpg  2020-10-08T13:12:50-34
# 1            caxton_dataset/print0/image-7.jpg  2020-10-08T13:12:50-80
# 2            caxton_dataset/print0/image-8.jpg  2020-10-08T13:12:51-27
# 3            caxton_dataset/print0/image-9.jpg  2020-10-08T13:12:51-74
# 4           caxton_dataset/print0/image-10.jpg  2020-10-08T13:12:52-20
# ...                                        ...                     ...
# 948391  caxton_dataset/print182/image-5428.jpg  2020-10-05T16:24:44-17
# 948392  caxton_dataset/print182/image-5429.jpg  2020-10-05T16:24:44-63
# 948393  caxton_dataset/print182/image-5430.jpg  2020-10-05T16:24:45-10
# 948394  caxton_dataset/print182/image-5431.jpg  2020-10-05T16:24:45-56
# 948395  caxton_dataset/print182/image-5432.jpg  2020-10-05T16:24:46-03
#
#         flow_rate  feed_rate  z_offset  target_hotend  hotend    bed  \
# ...
